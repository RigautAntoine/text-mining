# %%
import json, re, os, nltk, itertools, sklearn
import numpy as np
from nltk.corpus import treebank
from collections import Counter
import sklearn.metrics as metr

# %% [markdown]
# Get the data

# %%
corpus = list(treebank.tagged_words())

# %% [markdown]
# Filter for uninteresting tags

# %%
corpus = [(w, t) for w, t in corpus if t not in ['-NONE-', '-RRB-', '-LRB-']]

# %%
tags = [t for w, t in corpus]
words = [w for w, t in corpus]

# %%
print('{0} words, tag pairs in the dataset'.format(len(corpus)))
# Out:
# 93838 words, tag pairs in the dataset

# %%
tag_distribution = Counter([t for w, t in corpus])
print(len(tag_distribution.keys()), 'tags')
# Out:
# 43 tags

# %%
tag_distribution.most_common(5)
# Out:
# [('NN', 13166), ('IN', 9857), ('NNP', 9410), ('DT', 8165), ('NNS', 6047)]

# %% [markdown]
# # Parameter Estimation

# %%
tagset = list(set([t for w, t in corpus]))
print(tagset)
# Out:
# ['IN', '.', 'EX', 'RBS', ':', 'VBN', 'DT', 'NNP', 'TO', 'WRB', 'PRP', 'UH', 'JJR', 'CD', 'POS', '#', 'PDT', 'NNS', 'WDT', 'PRP$', 'WP', 'VB', 'CC', 'NNPS', 'VBZ', 'VBG', 'SYM', 'VBP', 'MD', '$', 'JJS', 'RBR', '``', 'WP$', 'JJ', 'VBD', ',', "''", 'RB', 'NN', 'RP', 'LS', 'FW']

# %%
index_to_vocabulary = list(set(words))

# %%
class Transition(dict):
    def __init__(self, tags, delta=0.5):
        self.delta = delta
        # Add a dummy tag START after each end-of-sentence tag '.'
        t_with_start = [[t] if t != '.' else [t, 'START'] for t in tags]
        self.tags = [t for tag in t_with_start for t in tag]
        # Find the conditional probability (a | b) which is the number of times a follows b. 
        self.bigram = Counter([(a, b) for b, a in zip(self.tags[:-1], self.tags[1:])])
        for key in self.bigram.keys():
            self[key] = self.bigram[key]
    
    def __call__(self, key):
        if key in self:
            return self[key] + self.delta
        else:
            return self.delta

# %%
class Emission(dict):
    def __init__(self, words, tags, sigma=0.1):
        self.sigma = sigma
        self.bigram = Counter([(a, b) for a, b in zip(words, tags)])
        for key in self.bigram.keys():
            self[key] = self.bigram[key]
            
    def __call__(self, key):
        if key in self:
            return (self[key] + self.sigma)
        else:
            return self.sigma

# %%
transition = Transition(tags, 0.5)

# %%
sorted([((t, 'VB'), transition((t, 'VB'))) for t in tagset], key = lambda x: -x[1])[0:10]
# Out:
# [(('DT', 'VB'), 607.5),
#  (('IN', 'VB'), 283.5),
#  (('VBN', 'VB'), 238.5),
#  (('JJ', 'VB'), 219.5),
#  (('NN', 'VB'), 171.5),
#  (('NNS', 'VB'), 115.5),
#  (('PRP$', 'VB'), 101.5),
#  (('TO', 'VB'), 94.5),
#  (('RB', 'VB'), 93.5),
#  (('PRP', 'VB'), 91.5)]

# %% [markdown]
# 'VB' usually followed by a determiner

# %%
emission = Emission(words, tags, 0.1)

# %%
sorted([((w, 'NN'), emission((w, 'NN'))) for w in index_to_vocabulary], key = lambda x: -x[1])[0:10]
# Out:
# [(('%', 'NN'), 445.1),
#  (('company', 'NN'), 260.1),
#  (('year', 'NN'), 212.1),
#  (('market', 'NN'), 176.1),
#  (('trading', 'NN'), 144.1),
#  (('stock', 'NN'), 136.1),
#  (('president', 'NN'), 133.1),
#  (('program', 'NN'), 127.1),
#  (('share', 'NN'), 116.1),
#  (('government', 'NN'), 83.1)]

# %% [markdown]
# ## Train a tagger

# %%
start = 0
sequences = []
for i in range(len(corpus)):
    if corpus[i][1] == '.':
        sequences.append(corpus[start:i+1])
        start = i+1

# %%
n = len(sequences)
X = [[w for w, tag in sequence] for sequence in sequences]
Y = [[tag for w, tag in sequence] for sequence in sequences]
print(n)
# Out:
# 3874

# %%
def tagger(sequence, states, transition, emission):
    T = len(sequence)
    N = len(states)
    treillis = np.zeros((N, T))
    max_came_from = {}
    
    # Initialization
    for s in range(N): 
        treillis[s, 0] = transition((states[s], 'START')) * emission((sequence[0], states[s]))
        max_came_from[s, 0] = 'START'
    
    # Recursion
    for t in range(1, T):
        for s in range(N):
            em = emission((sequence[t], states[s]))
            inputs = [transition((states[s], states[k])) * em * treillis[k, t-1] for k in range(N)]
            treillis[s, t] = np.max(inputs)
            max_came_from[s, t] = (np.argmax(inputs), t-1)
    
    # Reconstruct the path
    prev = (np.argmax(treillis[:, -1]), T-1)
    best_sequence = []
    while prev != 'START':
        best_sequence.append(states[prev[0]])
        prev = max_came_from[prev]
    return best_sequence[::-1]

# %%
arr = np.asarray([[4, 2, 9], [1, 6, 8], [12, 1, 1]])

# %%
arr
# Out:
# array([[ 4,  2,  9],
#        [ 1,  6,  8],
#        [12,  1,  1]])

# %%
np.argmax(arr[:,0])
# Out:
# 2

# %%
tagger(X[0][:-5], tagset, transition, emission)
# Out:
# ['NNP', 'NNP', ',', 'CD', 'NNS', 'JJ', ',', 'MD', 'VB', 'DT', 'NN', 'IN', 'DT']

# %% [markdown]
# ## Evaluation

# %%
folds = sklearn.cross_validation.KFold(n, n_folds=5, shuffle=True)

# %%
preds = []
for train_index, test_index in folds:
    X_train = [X[i] for i in train_index]
    y_train = [Y[i] for i in train_index]
    X_test = [X[i] for i in test_index]
    y_test = [Y[i] for i in test_index]
    
    transition = Transition(itertools.chain(*y_train), 0.5)
    emission = Emission(itertools.chain(*X_train), itertools.chain(*y_train), 0.1)
    
    true_pred = [(y, tagger(x, tagset, transition, emission)) for x, y in zip(X_test, y_test)]
    preds.append(true_pred)
# Out:
# C:\Users\Antoine\Anaconda3\lib\site-packages\ipykernel\__main__.py:16: RuntimeWarning: overflow encountered in double_scalars

# %%
def metrics(true_pred):
    rearranged = [(a, b) for true, pred in true_pred for a, b in zip(true, pred)]
    counts = Counter(rearranged)
    prec = {}
    rec = {}
    acc = 0
    for tag1 in tagset:
        TP = counts[(tag1, tag1)]
        FP = sum([counts[(tag2, tag1)] for tag2 in tagset]) - TP
        FN = sum([counts[(tag1, tag2)] for tag2 in tagset]) - TP
        try:
            prec[tag1] = TP / (TP + FP)
        except ZeroDivisionError:
            prec[tag1] = 1
        try:
            rec[tag1] = TP / (TP + FN)
        except ZeroDivisionError:
            rec[tag1] = 1
        acc += TP
    return [acc / len(rearranged), prec, rec]

# %%
metr = [metrics(true_pred) for true_pred in preds]

# %%
mean_accuracy = np.mean([acc for acc, prec, rec in metr])
print('Mean accuracy: %f' % mean_accuracy)
# Out:
# Mean accuracy: 0.867019

# %%
mean_precision = np.mean([np.mean(list(prec.values())) for acc, prec, rec in metr])
print('Mean precision: %f' % mean_precision)
# Out:
# Mean precision: 0.941576

# %%
mean_recall = np.mean([np.mean(list(rec.values())) for acc, prec, rec in metr])
print('Mean recall: %f' % mean_recall)
# Out:
# Mean recall: 0.605487

# %%
ts = ["NN", "VB", "JJR", "NNP"]

# %%
for t in ts:
    print('%s has precision %f, recall %f' % (t, np.mean([prec[t] for acc, prec, rec in metr]), np.mean([rec[t] for acc, prec, rec in metr])))
# Out:
# NN has precision 0.722528, recall 0.957182
# VB has precision 0.937887, recall 0.791853
# JJR has precision 0.771601, recall 0.205762
# NNP has precision 0.866466, recall 0.910429

# %% [markdown]
# ## Optimization

# %%
def metrics2(true_pred):
    acc, prec, rec = metrics(true_pred)
    return acc, np.mean(list(prec.values())), np.mean(list(rec.values()))

# %%
sigmas = [0.001, 0.01, 0.1, 1, 10, 100]
deltas = [0.005, 0.05, 0.5, 5, 50, 500]

# %%
perfs = []

# %%
j = 0
for train_index, test_index in folds:
    X_train = [X[i] for i in train_index]
    y_train = [Y[i] for i in train_index]
    X_test = [X[i] for i in test_index]
    y_test = [Y[i] for i in test_index]
    
    for sigma in sigmas:
        for delta in deltas:
            transition = Transition(itertools.chain(*y_train), delta)
            emission = Emission(itertools.chain(*X_train), itertools.chain(*y_train), sigma)
    
            true_pred = [(y, tagger(x, tagset, transition, emission)) for x, y in zip(X_test, y_test)]
            
            perfs.append((sigma, delta, metrics2(true_pred)))
            
            print('%d done.' % j)
            
            j += 1
# Out:
# 0 done.
# 1 done.
# 2 done.
# 3 done.
# 4 done.
# 5 done.
# 6 done.
# 7 done.
# 8 done.
# 9 done.
# 10 done.
# 11 done.
# 12 done.
# 13 done.
# 14 done.
# 15 done.
# 16 done.
# 17 done.
# 18 done.
# 19 done.
# 20 done.
# 21 done.
# 22 done.
# 23 done.
# 24 done.
# 25 done.
# 26 done.
# 27 done.
# 28 done.
# 29 done.
# 30 done.
# 31 done.
# 32 done.
# 33 done.
# 34 done.
# 35 done.
# 36 done.
# 37 done.
# 38 done.
# 39 done.
# 40 done.
# 41 done.
# 42 done.
# 43 done.
# 44 done.
# 45 done.
# 46 done.
# 47 done.
# 48 done.
# 49 done.
# 50 done.
# 51 done.
# 52 done.
# 53 done.
# 54 done.
# 55 done.
# 56 done.
# 57 done.
# 58 done.
# 59 done.
# 60 done.
# 61 done.
# 62 done.
# 63 done.
# 64 done.
# 65 done.
# 66 done.
# 67 done.
# 68 done.
# 69 done.
# 70 done.
# 71 done.
# 72 done.
# 73 done.
# 74 done.
# 75 done.
# 76 done.
# 77 done.
# 78 done.
# 79 done.
# 80 done.
# 81 done.
# 82 done.
# 83 done.
# 84 done.
# 85 done.
# 86 done.
# 87 done.
# 88 done.
# 89 done.
# 90 done.
# 91 done.
# 92 done.
# 93 done.
# 94 done.
# 95 done.
# 96 done.
# 97 done.
# 98 done.
# 99 done.
# 100 done.
# 101 done.
# 102 done.
# 103 done.
# 104 done.
# 105 done.
# 106 done.
# 107 done.
# 108 done.
# 109 done.
# 110 done.
# 111 done.
# 112 done.
# 113 done.
# 114 done.
# 115 done.
# 116 done.
# 117 done.
# 118 done.
# 119 done.
# 120 done.
# 121 done.
# 122 done.
# 123 done.
# 124 done.
# 125 done.
# 126 done.
# 127 done.
# 128 done.
# 129 done.
# 130 done.
# 131 done.
# 132 done.
# 133 done.
# 134 done.
# 135 done.
# 136 done.
# 137 done.
# 138 done.
# 139 done.
# 140 done.
# 141 done.
# 142 done.
# 143 done.
# 144 done.
# 145 done.
# 146 done.
# 147 done.
# 148 done.
# 149 done.
# 150 done.
# 151 done.
# 152 done.
# 153 done.
# 154 done.
# 155 done.
# 156 done.
# 157 done.
# 158 done.
# 159 done.
# 160 done.
# 161 done.
# 162 done.
# 163 done.
# 164 done.
# 165 done.
# 166 done.
# 167 done.
# 168 done.
# 169 done.
# 170 done.
# 171 done.
# 172 done.
# 173 done.
# 174 done.
# 175 done.
# 176 done.
# 177 done.
# 178 done.
# 179 done.
# C:\Users\Antoine\Anaconda3\lib\site-packages\ipykernel\__main__.py:16: RuntimeWarning: overflow encountered in double_scalars

# %%
perfs
# Out:
# [(0.001, 0.005, (0.9086522997748472, 0.9637471083347966, 0.75421292436970089)),
#  (0.001, 0.05, (0.9089739466066259, 0.96361559133511432, 0.75573491245473601)),
#  (0.001, 0.5, (0.9092419856331082, 0.96283441661295421, 0.75889626399700849)),
#  (0.001, 5, (0.9098316714913691, 0.96119091651371047, 0.77426509084181572)),
#  (0.001, 50, (0.9098852792966656, 0.93529529313050686, 0.78804027060899862)),
#  (0.001, 500, (0.9040420285193524, 0.91418427340072128, 0.79877464553060162)),
#  (0.01, 0.005, (0.9008791680068619, 0.96345147947662935, 0.7046560628907903)),
#  (0.01, 0.05, (0.9009327758121582, 0.96346125946927696, 0.70470121981108835)),
#  (0.01, 0.5, (0.9014688538651228, 0.96302815547564802, 0.70768825916982836)),
#  (0.01, 5, (0.9037203816875737, 0.96282225143620959, 0.732476084212066)),
#  (0.01, 50, (0.9082234373324756, 0.93654102923930838, 0.77919796074245729)),
#  (0.01, 500, (0.9037739894928701, 0.91414710117111042, 0.79849831912979219)),
#  (0.1, 0.005, (0.8709124048461456, 0.94108040670221516, 0.64402744077429885)),
#  (0.1, 0.05, (0.8710196204567385, 0.94029415710892328, 0.64408866119664776)),
#  (0.1, 0.5, (0.8714484828991101, 0.94036359264071712, 0.64469160766032008)),
#  (0.1, 5, (0.8743433043851184, 0.93937611859800374, 0.65404475211826019)),
#  (0.1, 50, (0.8838348495451365, 0.95258188127806553, 0.66876818585784725)),
#  (0.1, 500, (0.895946600635194, 0.93279977057582675, 0.76346482991707765)),
#  (1, 0.005, (0.7617483985573559, 0.95656341225986019, 0.4602925843197001)),
#  (1, 0.05, (0.7617483985573559, 0.95656341225986019, 0.4602925843197001)),
#  (1, 0.5, (0.7621252085912688, 0.95662602245634742, 0.46076644842796705)),
#  (1, 5, (0.7664854389836895, 0.95756695163240013, 0.46852792195547605)),
#  (1, 50, (0.7951768315659148, 0.95754274581676169, 0.52950524200801741)),
#  (1, 500, (0.8578887872099908, 0.93106952665109122, 0.69981127989205871)),
#  (10, 0.005, (0.5545028799052591, 0.94128617572064954, 0.26819080372456067)),
#  (10, 0.05, (0.5545028799052591, 0.94128617572064954, 0.26819080372456067)),
#  (10, 0.5, (0.5564407600796684, 0.94139573711088453, 0.27010479350418587)),
#  (10, 5, (0.5596705603703505, 0.94295562358877572, 0.2737570914567774)),
#  (10, 50, (0.5830327824729504, 0.94401780530396251, 0.3071501866361499)),
#  (10, 500, (0.7021585831942725, 0.92249704343147332, 0.49273874533332973)),
#  (100, 0.005, (0.38940625504656295, 0.93749744941665802, 0.15519942306171852)),
#  (100, 0.05, (0.3895139150562524, 0.93750519877152427, 0.15521700779816727)),
#  (100, 0.5, (0.3895139150562524, 0.9375090083409201, 0.15523406599373196)),
#  (100, 5, (0.38989072509016526, 0.93757679151926365, 0.15532872465924585)),
#  (100, 50, (0.3940894654680519, 0.91453999228675886, 0.15708805605540938)),
#  (100, 500, (0.4447973300317597, 0.91780634674775918, 0.20284584625759261)),
#  (0.001,
#   0.005,
#   (0.9044847477004625, 0.95779521623538921, 0.75721116055713533)),
#  (0.001, 0.05, (0.9045367146494829, 0.95780581939494336, 0.7572430178365237)),
#  (0.001, 0.5, (0.9048485163436054, 0.95589986585328257, 0.76070278753692255)),
#  (0.001, 5, (0.9055240866808709, 0.95438135248021971, 0.76883903238205631)),
#  (0.001, 50, (0.9052642519357689, 0.94992110149936515, 0.80607752405916921)),
#  (0.001, 500, (0.9002234578807878, 0.91217955826927266, 0.81941142898471875)),
#  (0.01, 0.005, (0.8971054409395625, 0.95500220735326258, 0.72381728958229641)),
#  (0.01, 0.05, (0.8971574078885829, 0.95501126404295389, 0.72385611397954763)),
#  (0.01, 0.5, (0.8973133087356441, 0.95498350754099881, 0.72420765892515837)),
#  (0.01, 5, (0.8997557553396041, 0.95561310056757187, 0.74025402917623773)),
#  (0.01, 50, (0.9034454087200541, 0.95073520779093468, 0.79437306041929567)),
#  (0.01, 500, (0.8999636231356857, 0.9121212000252118, 0.81929614543417195)),
#  (0.1, 0.005, (0.8681598503351868, 0.96156821469145504, 0.66261101333689887)),
#  (0.1, 0.05, (0.8681598503351868, 0.96156821469145504, 0.66261101333689887)),
#  (0.1, 0.5, (0.8686275528763706, 0.94538921688078714, 0.66389976071253398)),
#  (0.1, 5, (0.8726290079509432, 0.94598860856479794, 0.67789223190766434)),
#  (0.1, 50, (0.8875435223198046, 0.94898264663467957, 0.73020556550877636)),
#  (0.1, 500, (0.8990282180533181, 0.91417925322674376, 0.81539209144479874)),
#  (1, 0.005, (0.7647456217845451, 0.95692974129333419, 0.53999260566366514)),
#  (1, 0.05, (0.7647975887335654, 0.95693775501282197, 0.54000425687306075)),
#  (1, 0.5, (0.7653692251727902, 0.95704872866706503, 0.54062584079455966)),
#  (1, 5, (0.7694226471963831, 0.94631640151281082, 0.54727210812921845)),
#  (1, 50, (0.7972769318713299, 0.94839124439086964, 0.59850091262864369)),
#  (1, 500, (0.8613521800135114, 0.93971215722603307, 0.75329169783158356)),
#  (10, 0.005, (0.563633529075508, 0.94179077320968074, 0.3430694671498758)),
#  (10, 0.05, (0.5637374629735489, 0.9417990097295863, 0.34308663011220303)),
#  (10, 0.5, (0.5644130333108143, 0.94210942261962205, 0.34436815061932985)),
#  (10, 5, (0.5675830172010601, 0.94217809118573692, 0.34815506029434706)),
#  (10, 50, (0.592994855272047, 0.94310884546416873, 0.38124180199017166)),
#  (10, 500, (0.709452788026815, 0.92478654323198461, 0.56858281572663938)),
#  (100, 0.005, (0.3971314244140727, 0.93790079544643512, 0.22866047670942555)),
#  (100, 0.05, (0.39718339136309305, 0.93790470136077064, 0.22866905819058922)),
#  (100, 0.5, (0.3973912591591748, 0.93792803161626503, 0.22871070095707807)),
#  (100, 5, (0.39801486254741986, 0.93800145908519628, 0.22887808790379263)),
#  (100, 50, (0.4022241854180741, 0.93818361800202965, 0.23044162228990092)),
#  (100, 500, (0.45263212596788444, 0.93292620737547294, 0.27470787887437637))]

# %%
[rec for sigma, delta, (acc, prec, rec) in perfs]
# Out:
# [0.75421292436970089,
#  0.75573491245473601,
#  0.75889626399700849,
#  0.77426509084181572,
#  0.78804027060899862,
#  0.79877464553060162,
#  0.7046560628907903,
#  0.70470121981108835,
#  0.70768825916982836,
#  0.732476084212066,
#  0.77919796074245729,
#  0.79849831912979219,
#  0.64402744077429885,
#  0.64408866119664776,
#  0.64469160766032008,
#  0.65404475211826019,
#  0.72966775989789323,
#  0.79528788961263475,
#  0.51765960233352171,
#  0.51773045631214443,
#  0.5184423245842501,
#  0.52579457160626963,
#  0.58833386039422708,
#  0.74865889044191236,
#  0.32553388377209203,
#  0.32551588391609088,
#  0.3258187880404847,
#  0.32891123853843962,
#  0.35793373897646874,
#  0.54950798487910602,
#  0.20567483803985925,
#  0.20568383796785983,
#  0.20568383796785983,
#  0.20573661998483087,
#  0.20779960274117579,
#  0.25482624854428609,
#  0.68161532537342595,
#  0.68201213210797096,
#  0.68437143059892347,
#  0.71196266030091138,
#  0.7388330000692066,
#  0.74679185723948072,
#  0.62691673157204419,
#  0.62692577349037759,
#  0.63025702113376625,
#  0.65784560348196508,
#  0.72907077804499676,
#  0.74671188365128194,
#  0.56064295746896187,
#  0.56082826987001033,
#  0.56200925766787446,
#  0.57406314028230754,
#  0.65316449491024009,
#  0.7424476361773138,
#  0.434860127606569,
#  0.43484204376990221,
#  0.43519251918493362,
#  0.44063896275455267,
#  0.49960619900155578,
#  0.67646964229910356,
#  0.24742031110892934,
#  0.24746222123389358,
#  0.24745317931556016,
#  0.24891217543999128,
#  0.2795626675276347,
#  0.46624337126181675,
#  0.13462233218570752,
#  0.13468232614733855,
#  0.13467328422900515,
#  0.13482274528630767,
#  0.13659871191195858,
#  0.18283407734747242,
#  0.69251496552402858,
#  0.69369085118469398,
#  0.69416012250124215,
#  0.70190496319730256,
#  0.74058298355796581,
#  0.74650141546610416,
#  0.63220927809130434,
#  0.63234066687070256,
#  0.63418669542041084,
#  0.6597384315623217,
#  0.72466818491349305,
#  0.74640040852795986,
#  0.56744517469875799,
#  0.56744517469875799,
#  0.56816095942914191,
#  0.5845185438647571,
#  0.64191884942632471,
#  0.73947210859743395,
#  0.44648845883500465,
#  0.44649721808696458,
#  0.44719974396393253,
#  0.45402723675571938,
#  0.50552347128720421,
#  0.67945769060473482,
#  0.25179534586584973,
#  0.25176906810997007,
#  0.2518598136464068,
#  0.25571806350524173,
#  0.28604625542076684,
#  0.4703686659344562,
#  0.13512395440324471,
#  0.13512692865983855,
#  0.13512395440324471,
#  0.13552199761836906,
#  0.13734812196069879,
#  0.1800668554655305,
#  0.70447380185750308,
#  0.70526868452218383,
#  0.70714556304483123,
#  0.73134145497131786,
#  0.75931051664129967,
#  0.76903040112316601,
#  0.64751731950379376,
#  0.64784474245517176,
#  0.64999711527239035,
#  0.66756017214577568,
#  0.74746937219062504,
#  0.76894518246273991,
#  0.58721919462571148,
#  0.58735132993226535,
#  0.58867231862434755,
#  0.60741670182097962,
#  0.66876818585784725,
#  0.76346482991707765,
#  0.4602925843197001,
#  0.4602925843197001,
#  0.46076644842796705,
#  0.46852792195547605,
#  0.52950524200801741,
#  0.69981127989205871,
#  0.26819080372456067,
#  0.26819080372456067,
#  0.27010479350418587,
#  0.2737570914567774,
#  0.3071501866361499,
#  0.49273874533332973,
#  0.15519942306171852,
#  0.15521700779816727,
#  0.15523406599373196,
#  0.15532872465924585,
#  0.15708805605540938,
#  0.20284584625759261,
#  0.75721116055713533,
#  0.7572430178365237,
#  0.76070278753692255,
#  0.76883903238205631,
#  0.80607752405916921,
#  0.81941142898471875,
#  0.72381728958229641,
#  0.72385611397954763,
#  0.72420765892515837,
#  0.74025402917623773,
#  0.79437306041929567,
#  0.81929614543417195,
#  0.66261101333689887,
#  0.66261101333689887,
#  0.66389976071253398,
#  0.67789223190766434,
#  0.73020556550877636,
#  0.81539209144479874,
#  0.53999260566366514,
#  0.54000425687306075,
#  0.54062584079455966,
#  0.54727210812921845,
#  0.59850091262864369,
#  0.75329169783158356,
#  0.3430694671498758,
#  0.34308663011220303,
#  0.34436815061932985,
#  0.34815506029434706,
#  0.38124180199017166,
#  0.56858281572663938,
#  0.22866047670942555,
#  0.22866905819058922,
#  0.22871070095707807,
#  0.22887808790379263,
#  0.23044162228990092,
#  0.27470787887437637]
